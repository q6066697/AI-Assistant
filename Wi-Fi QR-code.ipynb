# %% [markdown]
# <a href="https://colab.research.google.com/github/q6066697/AI-Assistant/blob/main/Wi-Fi%20QR-code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wifi-qrcode-generator

# %%
# !pip install qrcode[pil] pillow

# %%
import wifi_qrcode_generator.generator
from PIL import Image

ssid = "CLCoding_WIFI"
password = "supersecret123"
security = "WPA"

from wifi_qrcode_generator.generator import wifi_qrcode
qr = wifi_qrcode(ssid, False, security, password)

qr.make_image().save("wifi_qr.png")
Image.open("wifi_qr.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=410x410>
